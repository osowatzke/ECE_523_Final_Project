# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Get path to files in repo. Can't get path of this notebook directly.
# So, each user must customize this path
# !cd /content/drive/MyDrive/ECE_523/repos/Final_Project/src

# %%
# Create run directory if one does not exist
# !mkdir -p ../runs
# !mkdir -p ../runs/custom_faster_rcnn

# Start tensorboard
# %reload_ext tensorboard
# %tensorboard --logdir ../runs/custom_faster_rcnn

# %%
# Run python source code
# %load fasterRCNN.py
# %run fasterRCNN.py
