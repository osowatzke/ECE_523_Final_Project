# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
torch.cuda.empty_cache()

# %%
# Get path to files in repo. Can't get path of this notebook directly.
# So, each user must customize this path
# %cd /content/drive/MyDrive/ECE_523/repos/Final_Project/src
# Out:
# /content/drive/MyDrive/ECE_523/repos/Final_Project/src

# %%
# %cd ECE_523_Final_Project/src/
# Out:
# [Errno 2] No such file or directory: 'ECE_523_Final_Project/src/'
# /content/drive/MyDrive/ECE_523/repos/Final_Project/src

# %%
# Clone github repo
# !git clone https://github.com/osowatzke/ECE_523_Final_Project

# !pip install torchmetrics
# Out:
# Cloning into 'ECE_523_Final_Project'...
# remote: Enumerating objects: 1175, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 1175 (delta 135), reused 131 (delta 68), pack-reused 966
# Receiving objects: 100% (1175/1175), 5.50 MiB | 10.06 MiB/s, done.
# Resolving deltas: 100% (656/656), done.

# %%
# !pip install torchmetrics

# %%
# %load ComputeMetrics.py

# %%
# %run ComputeMetrics.py -n 80 -c 1 -m .25 .25 .25
# Out:
# 'train' dataset exists. Bypassing download...
# 'val' dataset exists. Bypassing download...
# 'test' dataset exists. Bypassing download...
# Loading Images. Please be Patient...
# 0.00% Complete
# Eecution time: 2.3258817195892334
# {'map': tensor(0.0291), 'map_50': tensor(-1.), 'map_75': tensor(-1.), 'map_small': tensor(0.0223), 'map_medium': tensor(0.0925), 'map_large': tensor(0.2787), 'mar_1': tensor(0.0243), 'mar_10': tensor(0.0679), 'mar_100': tensor(0.0903), 'mar_small': tensor(0.0788), 'mar_medium': tensor(0.2188), 'mar_large': tensor(0.4549), 'map_per_class': tensor(-1.), 'mar_100_per_class': tensor(-1.), 'classes': tensor([ 1,  2,  3,  8,  9, 10, 14, 16], dtype=torch.int32)}
# IoU and mAP at 0.0: 0.017275353893637657
# ...

# %%
# %run ComputeMetrics.py -n 80 -c 2 -m .25 .25 .25
# Out:
# 'train' dataset exists. Bypassing download...
# 'val' dataset exists. Bypassing download...
# 'test' dataset exists. Bypassing download...
# Loading Images. Please be Patient...
# 0.00% Complete
# Eecution time: 2.354222536087036
# {'map': tensor(0.1165), 'map_50': tensor(-1.), 'map_75': tensor(-1.), 'map_small': tensor(0.0894), 'map_medium': tensor(0.2774), 'map_large': tensor(0.2787), 'mar_1': tensor(0.0971), 'mar_10': tensor(0.2714), 'mar_100': tensor(0.3613), 'mar_small': tensor(0.3153), 'mar_medium': tensor(0.6565), 'mar_large': tensor(0.4549), 'map_per_class': tensor(-1.), 'mar_100_per_class': tensor(-1.), 'classes': tensor([1, 3], dtype=torch.int32)}
# IoU and mAP at 0.0: 0.017275353893637657
# ...

# %%
# %run ComputeMetrics.py -n 100 -c 3 -m .25 .25 .25
# Out:
# 'train' dataset exists. Bypassing download...
# 'val' dataset exists. Bypassing download...
# 'test' dataset exists. Bypassing download...
# Loading Images. Please be Patient...
# 0.00% Complete
# Eecution time: 2.8578007221221924
# {'map': tensor(0.1068), 'map_50': tensor(-1.), 'map_75': tensor(-1.), 'map_small': tensor(0.0553), 'map_medium': tensor(0.3097), 'map_large': tensor(0.5510), 'mar_1': tensor(0.1077), 'mar_10': tensor(0.3000), 'mar_100': tensor(0.3538), 'mar_small': tensor(0.2788), 'mar_medium': tensor(0.6087), 'mar_large': tensor(0.8571), 'map_per_class': tensor(-1.), 'mar_100_per_class': tensor(-1.), 'classes': tensor(3, dtype=torch.int32)}
# IoU and mAP at 0.0: 0.032825905829668045
# ...

# %%
# %run ComputeMetrics.py -n 80 -c 4 -m .25 .25 .25
# Out:
# 'train' dataset exists. Bypassing download...
# 'val' dataset exists. Bypassing download...
# 'test' dataset exists. Bypassing download...
# Loading Images. Please be Patient...
# 0.00% Complete
# Eecution time: 2.3235373497009277
# {'map': tensor(0.1049), 'map_50': tensor(-1.), 'map_75': tensor(-1.), 'map_small': tensor(0.1099), 'map_medium': tensor(0.2335), 'map_large': tensor(0.0037), 'mar_1': tensor(0.0710), 'mar_10': tensor(0.2158), 'mar_100': tensor(0.3388), 'mar_small': tensor(0.3282), 'mar_medium': tensor(0.7083), 'mar_large': tensor(0.0526), 'map_per_class': tensor(-1.), 'mar_100_per_class': tensor(-1.), 'classes': tensor(1, dtype=torch.int32)}
# IoU and mAP at 0.0: 0.013133026659488678
# ...

# %%
# %run ComputeMetrics.py -n 100 -c 1 -m .25 .50 .75
# Out:
# 'train' dataset exists. Bypassing download...
# 'val' dataset exists. Bypassing download...
# 'test' dataset exists. Bypassing download...
# Loading Images. Please be Patient...
# 0.00% Complete
# Eecution time: 2.8599562644958496
# {'map': tensor(0.0096), 'map_50': tensor(0.0041), 'map_75': tensor(0.0002), 'map_small': tensor(0.0070), 'map_medium': tensor(0.0371), 'map_large': tensor(0.1388), 'mar_1': tensor(0.0097), 'mar_10': tensor(0.0270), 'mar_100': tensor(0.0353), 'mar_small': tensor(0.0293), 'mar_medium': tensor(0.1069), 'mar_large': tensor(0.2469), 'map_per_class': tensor(-1.), 'mar_100_per_class': tensor(-1.), 'classes': tensor([ 1,  2,  3,  8,  9, 10, 14, 16], dtype=torch.int32)}
# IoU and mAP at 0.0: 0.01587759144604206
# ...

# %%
# %run ComputeMetrics.py -n 80 -c 2 -m .25 .50 .75
# Out:
# 'train' dataset exists. Bypassing download...
# 'val' dataset exists. Bypassing download...
# 'test' dataset exists. Bypassing download...
# Loading Images. Please be Patient...
# 0.00% Complete
# Eecution time: 2.3726298809051514
# {'map': tensor(0.0456), 'map_50': tensor(0.0195), 'map_75': tensor(0.0008), 'map_small': tensor(0.0332), 'map_medium': tensor(0.1174), 'map_large': tensor(0.1397), 'mar_1': tensor(0.0439), 'mar_10': tensor(0.1175), 'mar_100': tensor(0.1546), 'mar_small': tensor(0.1283), 'mar_medium': tensor(0.3201), 'mar_large': tensor(0.2469), 'map_per_class': tensor(-1.), 'mar_100_per_class': tensor(-1.), 'classes': tensor([1, 3], dtype=torch.int32)}
# IoU and mAP at 0.0: 0.017275353893637657
# ...

# %%
# %run ComputeMetrics.py -n 80 -c 3 -m .25 .50 .75
# Out:
# 'train' dataset exists. Bypassing download...
# 'val' dataset exists. Bypassing download...
# 'test' dataset exists. Bypassing download...
# Loading Images. Please be Patient...
# 0.00% Complete
# Eecution time: 2.38206148147583
# {'map': tensor(0.0496), 'map_50': tensor(0.0204), 'map_75': tensor(0.0004), 'map_small': tensor(0.0262), 'map_medium': tensor(0.1223), 'map_large': tensor(0.2781), 'mar_1': tensor(0.0569), 'mar_10': tensor(0.1422), 'mar_100': tensor(0.1690), 'mar_small': tensor(0.1255), 'mar_medium': tensor(0.2791), 'mar_large': tensor(0.4762), 'map_per_class': tensor(-1.), 'mar_100_per_class': tensor(-1.), 'classes': tensor(3, dtype=torch.int32)}
# IoU and mAP at 0.0: 0.03639553114771843
# ...

# %%
# %run ComputeMetrics.py -n 80 -c 4 -m .25 .50 .75
# Out:
# 'train' dataset exists. Bypassing download...
# 'val' dataset exists. Bypassing download...
# 'test' dataset exists. Bypassing download...
# Loading Images. Please be Patient...
# 0.00% Complete
# Eecution time: 2.322333574295044
# {'map': tensor(0.0416), 'map_50': tensor(0.0187), 'map_75': tensor(0.0011), 'map_small': tensor(0.0403), 'map_medium': tensor(0.1126), 'map_large': tensor(0.0012), 'mar_1': tensor(0.0310), 'mar_10': tensor(0.0929), 'mar_100': tensor(0.1403), 'mar_small': tensor(0.1311), 'mar_medium': tensor(0.3611), 'mar_large': tensor(0.0175), 'map_per_class': tensor(-1.), 'mar_100_per_class': tensor(-1.), 'classes': tensor(1, dtype=torch.int32)}
# IoU and mAP at 0.0: 0.013133026659488678
# ...
